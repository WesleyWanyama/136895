# %%
#Importing the required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Loading the dataset
df = pd.read_csv("data/MALARIA_ITN_COVERAGE.csv")

# %%
df.head()
# Out:
#              GHO (CODE)                                      GHO (DISPLAY)  \
# 0  MALARIA_ITN_COVERAGE  Population with access to an insecticide-treat...
# 1  MALARIA_ITN_COVERAGE  Population with access to an insecticide-treat...
# 2  MALARIA_ITN_COVERAGE  Population with access to an insecticide-treat...
# 3  MALARIA_ITN_COVERAGE  Population with access to an insecticide-treat...
# 4  MALARIA_ITN_COVERAGE  Population with access to an insecticide-treat...
#
#                                            GHO (URL) PUBLISHSTATE (CODE)  \
# 0  https://www.who.int/data/gho/indicator-metadat...           PUBLISHED
# 1  https://www.who.int/data/gho/indicator-metadat...           PUBLISHED
# 2  https://www.who.int/data/gho/indicator-metadat...           PUBLISHED
# 3  https://www.who.int/data/gho/indicator-metadat...           PUBLISHED
# 4  https://www.who.int/data/gho/indicator-metadat...           PUBLISHED
#
#   PUBLISHSTATE (DISPLAY)  PUBLISHSTATE (URL)  YEAR (CODE)  YEAR (DISPLAY)  \
# 0              Published                 NaN         2021            2021
# 1              Published                 NaN         2009            2009
# 2              Published                 NaN         2015            2015
# 3              Published                 NaN         2002            2002
# 4              Published                 NaN         2019            2019
#
#    YEAR (URL) REGION (CODE)  ... COUNTRY (CODE)         COUNTRY (DISPLAY)  \
# 0         NaN           AFR  ...            BEN                     Benin
# 1         NaN           AFR  ...            GNB             Guinea-Bissau
# 2         NaN           AFR  ...            CAF  Central African Republic
# 3         NaN           AFR  ...            MDG                Madagascar
# 4         NaN           AFR  ...            GAB                     Gabon
#
#   COUNTRY (URL) Display Value   Numeric  Low  High  StdErr  StdDev  Comments
# 0           NaN         63.97  63.96720  NaN   NaN     NaN     NaN       NaN
# 1           NaN         14.67  14.67461  NaN   NaN     NaN     NaN       NaN
# 2           NaN         61.54  61.53668  NaN   NaN     NaN     NaN       NaN
# 3           NaN          3.34   3.34281  NaN   NaN     NaN     NaN       NaN
# 4           NaN         15.57  15.56833  NaN   NaN     NaN     NaN       NaN
#
# [5 rows x 22 columns]

# %%
df.describe()
# Out:
#        PUBLISHSTATE (URL)  YEAR (CODE)  YEAR (DISPLAY)  YEAR (URL)  \
# count                 0.0   880.000000      880.000000         0.0
# mean                  NaN  2010.500000     2010.500000         NaN
# std                   NaN     6.347897        6.347897         NaN
# min                   NaN  2000.000000     2000.000000         NaN
# 25%                   NaN  2005.000000     2005.000000         NaN
# 50%                   NaN  2010.500000     2010.500000         NaN
# 75%                   NaN  2016.000000     2016.000000         NaN
# max                   NaN  2021.000000     2021.000000         NaN
#
#        REGION (URL)  COUNTRY (URL)  Display Value     Numeric  Low  High  \
# count           0.0            0.0      880.00000  880.000000  0.0   0.0
# mean            NaN            NaN       31.08575   31.085732  NaN   NaN
# std             NaN            NaN       25.06330   25.063324  NaN   NaN
# min             NaN            NaN        2.14000    2.136610  NaN   NaN
# 25%             NaN            NaN        5.04750    5.047792  NaN   NaN
# 50%             NaN            NaN       26.16500   26.163510  NaN   NaN
# 75%             NaN            NaN       53.69750   53.698380  NaN   NaN
# max             NaN            NaN       89.17000   89.171550  NaN   NaN
#
#        StdErr  StdDev  Comments
# count     0.0     0.0       0.0
# mean      NaN     NaN       NaN
# std       NaN     NaN       NaN
# min       NaN     NaN       NaN
# 25%       NaN     NaN       NaN
# 50%       NaN     NaN       NaN
# 75%       NaN     NaN       NaN
# max       NaN     NaN       NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 880 entries, 0 to 879
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   GHO (CODE)              880 non-null    object
#  1   GHO (DISPLAY)           880 non-null    object
#  2   GHO (URL)               880 non-null    object
#  3   PUBLISHSTATE (CODE)     880 non-null    object
#  4   PUBLISHSTATE (DISPLAY)  880 non-null    object
#  5   PUBLISHSTATE (URL)      0 non-null      float64
#  6   YEAR (CODE)             880 non-null    int64
#  7   YEAR (DISPLAY)          880 non-null    int64
#  8   YEAR (URL)              0 non-null      float64
#  9   REGION (CODE)           880 non-null    object
#  10  REGION (DISPLAY)        880 non-null    object
#  11  REGION (URL)            0 non-null      float64
#  12  COUNTRY (CODE)          880 non-null    object
#  13  COUNTRY (DISPLAY)       880 non-null    object
#  14  COUNTRY (URL)           0 non-null      float64
#  15  Display Value           880 non-null    float64
#  16  Numeric                 880 non-null    float64
#  17  Low                     0 non-null      float64
#  18  High                    0 non-null      float64
#  19  StdErr                  0 non-null      float64
#  20  StdDev                  0 non-null      float64
#  21  Comments                0 non-null      float64
# dtypes: float64(11), int64(2), object(9)
# memory usage: 151.4+ KB

# %%
df.columns
# Out:
# Index(['GHO (CODE)', 'GHO (DISPLAY)', 'GHO (URL)', 'PUBLISHSTATE (CODE)',
#        'PUBLISHSTATE (DISPLAY)', 'PUBLISHSTATE (URL)', 'YEAR (CODE)',
#        'YEAR (DISPLAY)', 'YEAR (URL)', 'REGION (CODE)', 'REGION (DISPLAY)',
#        'REGION (URL)', 'COUNTRY (CODE)', 'COUNTRY (DISPLAY)', 'COUNTRY (URL)',
#        'Display Value', 'Numeric', 'Low', 'High', 'StdErr', 'StdDev',
#        'Comments'],
#       dtype='object')

# %%
#Specify the columns that are to be dropped
columns_to_drop = ['GHO (CODE)', 'GHO (DISPLAY)', 'GHO (URL)', 'PUBLISHSTATE (CODE)', 'PUBLISHSTATE (DISPLAY)', 'PUBLISHSTATE (URL)', 'YEAR (CODE)', 'YEAR (URL)', 'REGION (CODE)', 'REGION (URL)', 'COUNTRY (CODE)', 'COUNTRY (URL)', 'Display Value', 'Low', 'High', 'StdErr', 'StdDev', 'Comments']

# %%
#Drop the specified columns and create a new dataframe
df = df[[col for col in df.columns if col not in columns_to_drop]]

# %%
df.columns
# Out:
# Index(['YEAR (DISPLAY)', 'REGION (DISPLAY)', 'COUNTRY (DISPLAY)', 'Numeric'], dtype='object')

# %%
# Create a dictionary to specify the mapping of old column names to new column names
column_mapping = {
    'YEAR (DISPLAY)': 'Year',
    'REGION (DISPLAY)': 'Region',
    'COUNTRY (DISPLAY)': 'Country',
    'Numeric': 'Population',
}

# Use the rename() function to rename the columns
df.rename(columns=column_mapping, inplace=True)
# Out:
# C:\Users\Rona\AppData\Local\Temp\ipykernel_14820\1087864966.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns=column_mapping, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 880 entries, 0 to 879
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        880 non-null    int64
#  1   Region      880 non-null    object
#  2   Country     880 non-null    object
#  3   Population  880 non-null    float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 27.6+ KB

# %%
df.head()
# Out:
#    Year  Region                   Country  Population
# 0  2021  Africa                     Benin    63.96720
# 1  2009  Africa             Guinea-Bissau    14.67461
# 2  2015  Africa  Central African Republic    61.53668
# 3  2002  Africa                Madagascar     3.34281
# 4  2019  Africa                     Gabon    15.56833

# %%
# Convert 'Year' to datetime
df['Year'] = pd.to_datetime(df['Year'], format='%Y')
df['Year'] = df['Year'].dt.year
# Out:
# C:\Users\Rona\AppData\Local\Temp\ipykernel_14820\2991774388.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Year'] = pd.to_datetime(df['Year'], format='%Y')
# C:\Users\Rona\AppData\Local\Temp\ipykernel_14820\2991774388.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Year'] = df['Year'].dt.year

# %%
# Use astype to convert the "Cases" column to an integer
df['Population'] = df['Population'].astype(int)
# Out:
# C:\Users\Rona\AppData\Local\Temp\ipykernel_14820\2572990452.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Population'] = df['Population'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 880 entries, 0 to 879
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        880 non-null    int64
#  1   Region      880 non-null    object
#  2   Country     880 non-null    object
#  3   Population  880 non-null    int32
# dtypes: int32(1), int64(1), object(2)
# memory usage: 24.2+ KB

# %%
# Create a itn_coverage table with the selected columns
itn_coverage_table = df[['Year', 'Region', 'Country', 'Population']].copy()
# Add a new column 'itn_id' and set it as the index
itn_coverage_table['itn_id'] = range(1, len(itn_coverage_table) + 1)
# Reorder the columns to have 'case_id' as the first column
itn_coverage_table = itn_coverage_table[['itn_id', 'Year', 'Region', 'Country', 'Population']]

# %%
itn_coverage_table
# Out:
#      itn_id  Year  Region                   Country  Population
# 0         1  2021  Africa                     Benin          63
# 1         2  2009  Africa             Guinea-Bissau          14
# 2         3  2015  Africa  Central African Republic          61
# 3         4  2002  Africa                Madagascar           3
# 4         5  2019  Africa                     Gabon          15
# ..      ...   ...     ...                       ...         ...
# 875     876  2016  Africa                    Gambia          28
# 876     877  2001  Africa                     Niger           3
# 877     878  2007  Africa             Guinea-Bissau          22
# 878     879  2006  Africa             Cote d'Ivoire           3
# 879     880  2015  Africa              Burkina Faso          51
#
# [880 rows x 5 columns]
